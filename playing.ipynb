# %% [markdown]
# <a href="https://colab.research.google.com/github/shhhQuiettt/image-colorization/blob/main/playing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.utils.data import DataLoader
from datasets import load_dataset
from torchvision.transforms import Compose, ColorJitter, ToTensor

# %%
dataset = load_dataset("csr/Image-Colorization")["train"]
images
for pair in dataset:
  img = pair["image"]



# dataloader = DataLoader(dataset["train"], batch_size=4)
# it = iter(dataloader)
# next(it)
# Out:
# {'__key__': 'dataset_1k/train/2102360862', '__url__': '/root/.cache/huggingface/hub/datasets--csr--Image-Colorization/snapshots/9ee5911498089e2cb22d96ade80cc113e2439fd9/dataset_1k.tar.gz', 'jpg': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x600 at 0x7D1290BCB890>}
# {'__key__': 'dataset_1k/train/4439244465', '__url__': '/root/.cache/huggingface/hub/datasets--csr--Image-Colorization/snapshots/9ee5911498089e2cb22d96ade80cc113e2439fd9/dataset_1k.tar.gz', 'jpg': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x600 at 0x7D1290A18150>}
# {'__key__': 'dataset_1k/train/4504942754', '__url__': '/root/.cache/huggingface/hub/datasets--csr--Image-Colorization/snapshots/9ee5911498089e2cb22d96ade80cc113e2439fd9/dataset_1k.tar.gz', 'jpg': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x600 at 0x7D1290A18110>}
# ...

# %%
# !ls /root/.cache/huggingface/hub/datasets--csr--Image-Colorization/snapshots/9ee5911498089e2cb22d96ade80cc113e2439fd9/dataset_1k.tar.gz
# Out:
# /root/.cache/huggingface/hub/datasets--csr--Image-Colorization/snapshots/9ee5911498089e2cb22d96ade80cc113e2439fd9/dataset_1k.tar.gz
